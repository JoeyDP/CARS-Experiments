# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Experiments with iTALSs model

# %%
from pathlib import Path

import src.io as io
import src.evaluation as evaluation
import src.evaluation.splits
import src.evaluation.cars

from src.algorithm.cars.itals import iTALSs

# %% [markdown]
# ## Datasets

# %%
## Uncomment corresponding directory.
## RETARGET True for Frappe, False for the others

# DATA_DIR, RETARGET = Path('../../../data/CARS/Mobile_Frappe/'), True
DATA_DIR, RETARGET = Path('../../../data/CARS/Food_com/'), False
# DATA_DIR, RETARGET = Path('../../../data/CARS/TripAdvisor/'), False

# %%
# Shouldn't need to change this info
INTERACTIONS = DATA_DIR / 'interactions.csv'

SEED = 123456
SEED2 = 78910

ITEM_ID = 'item'
USER_ID = 'user'

# %% [markdown]
# ## Define algorithm and hyperparameter ranges

# %%
ALG = iTALSs


K = [80]
MAX_IT = [10]
DEFAULT_CONTEXT_1 = [True]

# L2 = [100, 1000, 10000, 100000]
# V = [0, 0.5, 1]
# ALPHA = [100, 1000, 10000, 100000]

# L2 = [100000, 1e6, 1e7, 1e8]
# V = [0.75, 1]
# ALPHA = [1000, 10000, 100000]

L2 = [50000, 100000, 200000]
V = [0.75, 1]
ALPHA = [5000, 10000, 20000]

HYPERPARAMS = {'k': K, 'l2': L2, 'v': V, 'alpha': ALPHA, 'max_iterations': MAX_IT, 'default_context_1': DEFAULT_CONTEXT_1}
HYPERPARAMS
# Out:
# {'k': [80],
#  'l2': [50000, 100000, 200000],
#  'v': [0.75, 1],
#  'alpha': [5000, 10000, 20000],
#  'max_iterations': [10],
#  'default_context_1': [True]}

# %% [markdown]
# ## Parse data

# %%
data = io.parse_interactions_with_context(INTERACTIONS, item_id=ITEM_ID, user_id=USER_ID)
data.df
# Out:
#         userId  itemId  dayType  season
# 0        20600    4089        1       1
# 1        18959    4089        2       2
# 2        13015    4089        2       3
# 3         7722    4089        1       3
# 4        19126    4089        2       2
# ...        ...     ...      ...     ...
# 423358     960    5168        1       3
# 423359    4391    5168        2       4
# 423360    3138    5168        2       1
# 423361     807    5168        2       2
# 423362    3068    5168        2       4
#
# [423363 rows x 4 columns]

# %% [markdown]
# ## Make train/val split for hyperparam tuning

# %%
train, test = evaluation.splits.context_leave_one_out_split(data, seed=SEED)

# %% [markdown]
# ## Perform gridsearch on validation set

# %%
# %%time
score, best_hyperparams = evaluation.cars.gridsearch(ALG, train, test, HYPERPARAMS, retarget=RETARGET)
f"Best score of {score} achieved with {best_hyperparams}."
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.02
# Average Recall@20 0.052
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.021
# Average Recall@20 0.051
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.009
# MRR@20 0.012
# Average Recall@5 0.019
# Average Recall@20 0.052
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 50000, 'v': 1, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.015
# MRR@20 0.018
# Average Recall@5 0.025
# Average Recall@20 0.06
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.023
# Average Recall@20 0.054
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200000, 'v': 1, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.009
# MRR@20 0.012
# Average Recall@5 0.02
# Average Recall@20 0.053
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.023
# Average Recall@20 0.057
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.022
# Average Recall@20 0.052
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200000, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.009
# MRR@20 0.012
# Average Recall@5 0.02
# Average Recall@20 0.049
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 50000, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.023
# Average Recall@20 0.055
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200000, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.022
# Average Recall@20 0.052
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 20000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.018
# Average Recall@20 0.042
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 0.75, 'alpha': 20000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.022
# Average Recall@20 0.053
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200000, 'v': 0.75, 'alpha': 20000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.02
# Average Recall@20 0.049
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 50000, 'v': 1, 'alpha': 20000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.009
# MRR@20 0.012
# Average Recall@5 0.016
# Average Recall@20 0.043
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 20000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.012
# MRR@20 0.014
# Average Recall@5 0.02
# Average Recall@20 0.047
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200000, 'v': 1, 'alpha': 20000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.049
# CPU times: user 18min 57s, sys: 3min 55s, total: 22min 52s
# Wall time: 52min 30s
# "Best score of 0.017848031167153208 achieved with {'k': 80, 'l2': 50000, 'v': 1, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}."

# %% [markdown]
# ## Evaluate model with optimal hyperparams with KFolds Cross validation

# %%
# %%time
alg = ALG(**best_hyperparams)
results = evaluation.cars.contextKFoldsEval(alg, data, nr_folds=5, seed=SEED2, retarget=RETARGET)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.014 (0.0)
# MRR@20 0.017 (0.0)
# Average Recall@5 0.024 (0.001)
# Average Recall@20 0.058 (0.002)
# CPU times: user 5min 14s, sys: 1min, total: 6min 15s
# Wall time: 14min 28s
