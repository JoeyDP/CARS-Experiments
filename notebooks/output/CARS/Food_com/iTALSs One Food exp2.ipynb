# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Experiments with iTALSs model

# %%
from pathlib import Path

import src.io as io
import src.evaluation as evaluation
import src.evaluation.splits
import src.evaluation.cars

from src.algorithm.cars.itals import iTALSs

# %% [markdown]
# ## Datasets

# %%
## Uncomment corresponding directory.
## RETARGET True for Frappe, False for the others

# DATA_DIR, RETARGET = Path('../../../data/CARS/Mobile_Frappe/'), True
DATA_DIR, RETARGET = Path('../../../data/CARS/Food_com/'), False
# DATA_DIR, RETARGET = Path('../../../data/CARS/TripAdvisor/'), False

# %%
# Shouldn't need to change this info
INTERACTIONS = DATA_DIR / 'interactions.csv'

SEED = 123456
SEED2 = 78910

ITEM_ID = 'item'
USER_ID = 'user'

# %% [markdown]
# ## Define algorithm and hyperparameter ranges

# %%
ALG = iTALSs


K = [80]
MAX_IT = [10]
DEFAULT_CONTEXT_1 = [True]

# L2 = [100, 1000, 10000, 100000]
# V = [0, 0.5, 1]
# ALPHA = [100, 1000, 10000, 100000]

L2 = [100000, 1e6, 1e7, 1e8]
V = [0.75, 1]
ALPHA = [1000, 10000, 100000]

# L2 = [5000, 10000, 15000, 20000, 50000]
# V = [0.75, 1]
# ALPHA = [500, 1000, 1500, 2000, 5000]

HYPERPARAMS = {'k': K, 'l2': L2, 'v': V, 'alpha': ALPHA, 'max_iterations': MAX_IT, 'default_context_1': DEFAULT_CONTEXT_1}
HYPERPARAMS
# Out:
# {'k': [80],
#  'l2': [100000, 1000000.0, 10000000.0, 100000000.0],
#  'v': [0.75, 1],
#  'alpha': [1000, 10000, 100000],
#  'max_iterations': [10],
#  'default_context_1': [True]}

# %% [markdown]
# ## Parse data

# %%
data = io.parse_interactions_with_context(INTERACTIONS, item_id=ITEM_ID, user_id=USER_ID)
data.df
# Out:
#         userId  itemId  dayType  season
# 0        20600    4089        1       1
# 1        18959    4089        2       2
# 2        13015    4089        2       3
# 3         7722    4089        1       3
# 4        19126    4089        2       2
# ...        ...     ...      ...     ...
# 423358     960    5168        1       3
# 423359    4391    5168        2       4
# 423360    3138    5168        2       1
# 423361     807    5168        2       2
# 423362    3068    5168        2       4
#
# [423363 rows x 4 columns]

# %% [markdown]
# ## Make train/val split for hyperparam tuning

# %%
train, test = evaluation.splits.context_leave_one_out_split(data, seed=SEED)

# %% [markdown]
# ## Perform gridsearch on validation set

# %%
# %%time
score, best_hyperparams = evaluation.cars.gridsearch(ALG, train, test, HYPERPARAMS, retarget=RETARGET)
f"Best score of {score} achieved with {best_hyperparams}."
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.009
# Average Recall@5 0.014
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1000000.0, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.009
# Average Recall@5 0.014
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10000000.0, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.009
# Average Recall@5 0.014
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000000.0, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.009
# Average Recall@5 0.014
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.007
# MRR@20 0.01
# Average Recall@5 0.014
# Average Recall@20 0.05
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1000000.0, 'v': 1, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.004
# MRR@20 0.006
# Average Recall@5 0.009
# Average Recall@20 0.032
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10000000.0, 'v': 1, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.004
# MRR@20 0.006
# Average Recall@5 0.009
# Average Recall@20 0.032
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000000.0, 'v': 1, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.004
# MRR@20 0.006
# Average Recall@5 0.009
# Average Recall@20 0.032
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.022
# Average Recall@20 0.052
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1000000.0, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.008
# Average Recall@5 0.014
# Average Recall@20 0.04
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10000000.0, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.008
# Average Recall@5 0.014
# Average Recall@20 0.04
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000000.0, 'v': 0.75, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.008
# Average Recall@5 0.014
# Average Recall@20 0.04
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.022
# Average Recall@20 0.056
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1000000.0, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.001
# MRR@20 0.002
# Average Recall@5 0.002
# Average Recall@20 0.011
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10000000.0, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.001
# MRR@20 0.002
# Average Recall@5 0.002
# Average Recall@20 0.011
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000000.0, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.001
# MRR@20 0.002
# Average Recall@5 0.002
# Average Recall@20 0.011
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 0.75, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.006
# MRR@20 0.008
# Average Recall@5 0.011
# Average Recall@20 0.027
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1000000.0, 'v': 0.75, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.007
# MRR@20 0.01
# Average Recall@5 0.013
# Average Recall@20 0.047
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10000000.0, 'v': 0.75, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.008
# MRR@20 0.011
# Average Recall@5 0.014
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000000.0, 'v': 0.75, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.008
# MRR@20 0.011
# Average Recall@5 0.014
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.008
# MRR@20 0.01
# Average Recall@5 0.013
# Average Recall@20 0.034
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1000000.0, 'v': 1, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.007
# MRR@20 0.009
# Average Recall@5 0.015
# Average Recall@20 0.042
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10000000.0, 'v': 1, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.001
# MRR@20 0.001
# Average Recall@5 0.001
# Average Recall@20 0.005
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100000000.0, 'v': 1, 'alpha': 100000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.001
# MRR@20 0.001
# Average Recall@5 0.001
# Average Recall@20 0.005
# CPU times: user 25min 35s, sys: 5min 20s, total: 30min 55s
# Wall time: 1h 10min 59s
# "Best score of 0.016494904283748058 achieved with {'k': 80, 'l2': 100000, 'v': 1, 'alpha': 10000, 'max_iterations': 10, 'default_context_1': True}."

# %% [markdown]
# ## Evaluate model with optimal hyperparams with KFolds Cross validation

# %%
# %%time
alg = ALG(**best_hyperparams)
results = evaluation.cars.contextKFoldsEval(alg, data, nr_folds=5, seed=SEED2, retarget=RETARGET)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 23803 users
# MRR@5 0.012 (0.001)
# MRR@20 0.015 (0.001)
# Average Recall@5 0.022 (0.001)
# Average Recall@20 0.054 (0.001)
# CPU times: user 5min 24s, sys: 1min 4s, total: 6min 29s
# Wall time: 14min 40s
