# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Experiments with WTF model

# %%
from pathlib import Path

import src.io as io
import src.evaluation as evaluation
import src.evaluation.splits
import src.evaluation.cars

from src.algorithm.cars.wtf import WTF

# %% [markdown]
# ## Datasets

# %%
## Uncomment corresponding directory.
## RETARGET True for Frappe, False for the others

# DATA_DIR, RETARGET = Path('../../../data/CARS/Mobile_Frappe/'), True
DATA_DIR, RETARGET = Path('../../../data/CARS/Food_com/'), False
# DATA_DIR, RETARGET = Path('../../../data/CARS/TripAdvisor/'), False

# %%
# Shouldn't need to change this info
INTERACTIONS = DATA_DIR / 'interactions.csv'

SEED = 123456
SEED2 = 78910

ITEM_ID = 'item'
USER_ID = 'user'

# %% [markdown]
# ## Define algorithm and hyperparameter ranges

# %%
ALG = WTF

K = [80]
MAX_IT = [10]
DEFAULT_CONTEXT_1 = [True]

# L2 = [100, 1000, 10000, 100000]
# V = [0, 0.5, 1]
# ALPHA = [100, 1000, 10000, 100000]

L2 = [5000, 10000, 20000, 50000]
V = [0.25, 0.5, 0.75]
ALPHA = [500, 1000, 2000, 5000]

HYPERPARAMS = {'k': K, 'l2': L2, 'v': V, 'alpha': ALPHA, 'max_iterations': MAX_IT, 'default_context_1': DEFAULT_CONTEXT_1}
HYPERPARAMS
# Out:
# {'k': [80],
#  'l2': [5000, 10000, 20000, 50000],
#  'v': [0.25, 0.5, 0.75],
#  'alpha': [500, 1000, 2000, 5000],
#  'max_iterations': [10],
#  'default_context_1': [True]}

# %% [markdown]
# ## Parse data

# %%
data = io.parse_interactions_with_context(INTERACTIONS, item_id=ITEM_ID, user_id=USER_ID)
data.df
# Out:
#         userId  itemId  season  weekday
# 0        19211    6280       1        1
# 1        17684    6280       2        2
# 2        12110    6280       3        3
# 3         7184    6280       3        1
# 4        17837    6280       2        4
# ...        ...     ...     ...      ...
# 388357     895    7799       3        7
# 388358    4100    7799       4        2
# 388359    2940    7799       1        4
# 388360     757    7799       2        2
# 388361    2876    7799       4        3
#
# [388362 rows x 4 columns]

# %% [markdown]
# ## Make train/val split for hyperparam tuning

# %%
train, test = evaluation.splits.context_leave_one_out_split(data, seed=SEED)

# %% [markdown]
# ## Perform gridsearch on validation set

# %%
# %%time
score, best_hyperparams = evaluation.cars.gridsearch(ALG, train, test, HYPERPARAMS, retarget=RETARGET)
f"Best score of {score} achieved with {best_hyperparams}."
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.25, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.024
# Average Recall@20 0.054
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.25, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.023
# Average Recall@20 0.063
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.25, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.057
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.25, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.5, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.014
# MRR@20 0.018
# Average Recall@5 0.024
# Average Recall@20 0.06
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.5, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.024
# Average Recall@20 0.061
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.5, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.5, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.014
# Average Recall@5 0.02
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.75, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.015
# MRR@20 0.018
# Average Recall@5 0.024
# Average Recall@20 0.057
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.75, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.017
# Average Recall@5 0.025
# Average Recall@20 0.062
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.75, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 500, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.25, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.021
# Average Recall@20 0.049
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.25, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.017
# Average Recall@5 0.023
# Average Recall@20 0.058
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.25, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.022
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.25, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.014
# Average Recall@5 0.02
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.5, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.022
# Average Recall@20 0.051
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.5, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.015
# MRR@20 0.019
# Average Recall@5 0.027
# Average Recall@20 0.064
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.5, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.057
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.5, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.021
# Average Recall@20 0.05
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.016
# MRR@20 0.019
# Average Recall@5 0.027
# Average Recall@20 0.062
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.057
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 1000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.25, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.044
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.25, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.02
# Average Recall@20 0.051
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.25, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.023
# Average Recall@20 0.059
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.25, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.057
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.5, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.046
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.5, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.024
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.5, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.014
# MRR@20 0.018
# Average Recall@5 0.025
# Average Recall@20 0.063
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.5, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.75, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.015
# Average Recall@5 0.021
# Average Recall@20 0.047
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.75, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.014
# MRR@20 0.016
# Average Recall@5 0.024
# Average Recall@20 0.055
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.75, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.016
# MRR@20 0.02
# Average Recall@5 0.028
# Average Recall@20 0.066
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.022
# Average Recall@20 0.057
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.25, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.009
# MRR@20 0.01
# Average Recall@5 0.014
# Average Recall@20 0.032
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.25, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.018
# Average Recall@20 0.046
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.25, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.02
# Average Recall@20 0.053
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.25, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.022
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.5, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.015
# Average Recall@20 0.037
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.5, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.02
# Average Recall@20 0.049
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.5, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.022
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.5, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.016
# Average Recall@5 0.023
# Average Recall@20 0.058
# Training model WTF with hyperparameters {'k': 80, 'l2': 5000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.017
# Average Recall@20 0.04
# Training model WTF with hyperparameters {'k': 80, 'l2': 10000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.015
# Average Recall@5 0.021
# Average Recall@20 0.047
# Training model WTF with hyperparameters {'k': 80, 'l2': 20000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.022
# Average Recall@20 0.056
# Training model WTF with hyperparameters {'k': 80, 'l2': 50000, 'v': 0.75, 'alpha': 5000, 'max_iterations': 10, 'default_context_1': True}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.013
# MRR@20 0.016
# Average Recall@5 0.023
# Average Recall@20 0.059
# CPU times: user 58min 58s, sys: 12min 36s, total: 1h 11min 34s
# Wall time: 2h 54min 20s
# "Best score of 0.01955527244295372 achieved with {'k': 80, 'l2': 20000, 'v': 0.75, 'alpha': 2000, 'max_iterations': 10, 'default_context_1': True}."

# %% [markdown]
# ## Evaluate model with optimal hyperparams with KFolds Cross validation

# %%
# %%time
alg = ALG(**best_hyperparams)
results = evaluation.cars.contextKFoldsEval(alg, data, nr_folds=5, seed=SEED2, retarget=RETARGET)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.016 (0.0)
# MRR@20 0.019 (0.0)
# Average Recall@5 0.028 (0.001)
# Average Recall@20 0.065 (0.001)
# CPU times: user 6min 26s, sys: 1min 17s, total: 7min 43s
# Wall time: 18min 28s
