# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Experiments with iTALSs model

# %%
from pathlib import Path

import src.io as io
import src.evaluation as evaluation
import src.evaluation.splits
import src.evaluation.cars

from src.algorithm.cars.itals import iTALSs

# %% [markdown]
# ## Datasets

# %%
## Uncomment corresponding directory.
## RETARGET True for Frappe, False for the others

# DATA_DIR, RETARGET = Path('../../../data/CARS/Mobile_Frappe/'), True
DATA_DIR, RETARGET = Path('../../../data/CARS/Food_com/'), False
# DATA_DIR, RETARGET = Path('../../../data/CARS/TripAdvisor/'), False

# %%
# Shouldn't need to change this info
INTERACTIONS = DATA_DIR / 'interactions.csv'

SEED = 123456
SEED2 = 78910

ITEM_ID = 'item'
USER_ID = 'user'

# %% [markdown]
# ## Define algorithm and hyperparameter ranges

# %%
ALG = iTALSs


K = [80]
MAX_IT = [10]
DEFAULT_CONTEXT_1 = [False]

# L2 = [100, 1000, 10000, 100000]
# V = [0, 0.5, 1]
# ALPHA = [100, 1000, 10000, 100000]

L2 = [1, 10, 100, 200]
V = [0.25, 0.5, 0.75]
ALPHA = [1, 10, 100, 200]


HYPERPARAMS = {'k': K, 'l2': L2, 'v': V, 'alpha': ALPHA, 'max_iterations': MAX_IT, 'default_context_1': DEFAULT_CONTEXT_1}
HYPERPARAMS
# Out:
# {'k': [80],
#  'l2': [1, 10, 100, 200],
#  'v': [0.25, 0.5, 0.75],
#  'alpha': [1, 10, 100, 200],
#  'max_iterations': [10],
#  'default_context_1': [False]}

# %% [markdown]
# ## Parse data

# %%
data = io.parse_interactions_with_context(INTERACTIONS, item_id=ITEM_ID, user_id=USER_ID)
data.df
# Out:
#         userId  itemId  season  weekday
# 0        19211    6280       1        1
# 1        17684    6280       2        2
# 2        12110    6280       3        3
# 3         7184    6280       3        1
# 4        17837    6280       2        4
# ...        ...     ...     ...      ...
# 388357     895    7799       3        7
# 388358    4100    7799       4        2
# 388359    2940    7799       1        4
# 388360     757    7799       2        2
# 388361    2876    7799       4        3
#
# [388362 rows x 4 columns]

# %% [markdown]
# ## Make train/val split for hyperparam tuning

# %%
train, test = evaluation.splits.context_leave_one_out_split(data, seed=SEED)

# %% [markdown]
# ## Perform gridsearch on validation set

# %%
# %%time
score, best_hyperparams = evaluation.cars.gridsearch(ALG, train, test, HYPERPARAMS, retarget=RETARGET)
f"Best score of {score} achieved with {best_hyperparams}."
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.25, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.008
# MRR@20 0.011
# Average Recall@5 0.018
# Average Recall@20 0.043
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.25, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.25, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.25, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.5, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.009
# MRR@20 0.012
# Average Recall@5 0.018
# Average Recall@20 0.044
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.5, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.5, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.5, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.019
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.25, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.019
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.25, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.009
# MRR@20 0.012
# Average Recall@5 0.018
# Average Recall@20 0.046
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.25, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.25, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.5, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.018
# Average Recall@20 0.043
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.5, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.022
# Average Recall@20 0.056
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.5, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.5, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.018
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.02
# Average Recall@20 0.054
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.25, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.018
# Average Recall@20 0.044
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.25, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.014
# Average Recall@5 0.02
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.25, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.02
# Average Recall@20 0.05
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.25, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.054
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.5, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.019
# Average Recall@20 0.042
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.5, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.5, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.021
# Average Recall@20 0.056
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.5, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.045
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.013
# Average Recall@5 0.018
# Average Recall@20 0.043
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.055
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.25, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.013
# Average Recall@5 0.018
# Average Recall@20 0.039
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.25, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.041
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.25, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.013
# Average Recall@5 0.018
# Average Recall@20 0.041
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.25, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.047
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.5, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.017
# Average Recall@20 0.038
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.5, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.013
# Average Recall@5 0.019
# Average Recall@20 0.042
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.5, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.044
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.5, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011
# MRR@20 0.014
# Average Recall@5 0.02
# Average Recall@20 0.052
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 1, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.01
# MRR@20 0.012
# Average Recall@5 0.016
# Average Recall@20 0.039
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 10, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.014
# Average Recall@5 0.019
# Average Recall@20 0.043
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.012
# MRR@20 0.015
# Average Recall@5 0.021
# Average Recall@20 0.049
# Training model iTALSs with hyperparameters {'k': 80, 'l2': 200, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': False}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.0
# MRR@20 0.0
# Average Recall@5 0.0
# Average Recall@20 0.001
# CPU times: user 41min 38s, sys: 7min 49s, total: 49min 27s
# Wall time: 1h 52min 24s
# "Best score of 0.014830456184354156 achieved with {'k': 80, 'l2': 10, 'v': 0.5, 'alpha': 10, 'max_iterations': 10, 'default_context_1': False}."

# %% [markdown]
# ## Evaluate model with optimal hyperparams with KFolds Cross validation

# %%
# %%time
alg = ALG(**best_hyperparams)
results = evaluation.cars.contextKFoldsEval(alg, data, nr_folds=5, seed=SEED2, retarget=RETARGET)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 22178 users
# MRR@5 0.011 (0.0)
# MRR@20 0.014 (0.0)
# Average Recall@5 0.021 (0.001)
# Average Recall@20 0.053 (0.001)
# CPU times: user 4min 39s, sys: 49.6 s, total: 5min 28s
# Wall time: 12min 11s
