# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Experiments with WTF model

# %%
from pathlib import Path

import src.io as io
import src.evaluation as evaluation
import src.evaluation.splits
import src.evaluation.cars

from src.algorithm.cars.wtf import WTF

# %% [markdown]
# ## Datasets

# %%
## Uncomment corresponding directory.
## RETARGET True for Frappe, False for the others

# DATA_DIR, RETARGET = Path('../../../data/CARS/Mobile_Frappe/'), True
# DATA_DIR, RETARGET = Path('../../../data/CARS/Food_com/'), False
DATA_DIR, RETARGET = Path('../../../data/CARS/TripAdvisor/'), False

# %%
# Shouldn't need to change this info
INTERACTIONS = DATA_DIR / 'interactions.csv'

SEED = 123456
SEED2 = 78910

ITEM_ID = 'item'
USER_ID = 'user'

# %% [markdown]
# ## Define algorithm and hyperparameter ranges

# %%
ALG = WTF

K = [80]
MAX_IT = [10]
DEFAULT_CONTEXT_1 = [True]
MAX_CG_IT = [10]

# L2 = [100, 1000, 10000, 100000]
# V = [0, 0.5, 1]
# ALPHA = [100, 1000, 10000, 100000]

# L2 = [5000, 10000, 20000, 50000]
# V = [0.25, 0.5, 0.75]
# ALPHA = [500, 1000, 2000, 5000]

L2 = [100, 500, 1000, 2000]
V = [0.75, 1]
ALPHA = [1, 10, 50, 100, 200]

HYPERPARAMS = {'k': K, 'l2': L2, 'v': V, 'alpha': ALPHA, 'max_iterations': MAX_IT, 'default_context_1': DEFAULT_CONTEXT_1, 'max_cg_iter': MAX_CG_IT}
HYPERPARAMS
# Out:
# {'k': [80],
#  'l2': [100, 500, 1000, 2000],
#  'v': [0.75, 1],
#  'alpha': [1, 10, 50, 100, 200],
#  'max_iterations': [10],
#  'default_context_1': [True],
#  'max_cg_iter': [10]}

# %% [markdown]
# ## Parse data

# %%
data = io.parse_interactions_with_context(INTERACTIONS, item_id=ITEM_ID, user_id=USER_ID)
data.df
# Out:
#        userId  itemId  TripType  UserState
# 0        1899    1865         1          1
# 1         466     721         1          1
# 2        1992     451         2          1
# 3         466    1016         1          1
# 4        1441     414         3          1
# ...       ...     ...       ...        ...
# 12831     936     341         3         78
# 12832    1545    1936         3         78
# 12833     399    1556         2         79
# 12834     918    1380         5         79
# 12835     399     264         2         79
#
# [12836 rows x 4 columns]

# %% [markdown]
# ## Make train/val split for hyperparam tuning

# %%
train, test = evaluation.splits.context_leave_one_out_split(data, seed=SEED)

# %% [markdown]
# ## Perform gridsearch on validation set

# %%
# %%time
score, best_hyperparams = evaluation.cars.gridsearch(ALG, train, test, HYPERPARAMS, retarget=RETARGET)
f"Best score of {score} achieved with {best_hyperparams}."
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.068
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 0.75, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 1, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 1, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 1, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 1, 'alpha': 1, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.02
# MRR@20 0.024
# Average Recall@5 0.037
# Average Recall@20 0.087
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 0.75, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.068
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 1, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.017
# MRR@20 0.022
# Average Recall@5 0.03
# Average Recall@20 0.081
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 1, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 1, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 1, 'alpha': 10, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.018
# MRR@20 0.024
# Average Recall@5 0.038
# Average Recall@20 0.097
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 0.75, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.022
# MRR@20 0.028
# Average Recall@5 0.039
# Average Recall@20 0.094
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 0.75, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.068
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 0.75, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 1, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.022
# MRR@20 0.027
# Average Recall@5 0.036
# Average Recall@20 0.09
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 1, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.021
# MRR@20 0.026
# Average Recall@5 0.035
# Average Recall@20 0.088
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 1, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.02
# Average Recall@20 0.075
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 1, 'alpha': 50, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.067
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.022
# MRR@20 0.029
# Average Recall@5 0.044
# Average Recall@20 0.112
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.021
# MRR@20 0.026
# Average Recall@5 0.038
# Average Recall@20 0.094
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.023
# MRR@20 0.029
# Average Recall@5 0.041
# Average Recall@20 0.097
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 0.75, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.068
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 1, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.02
# MRR@20 0.026
# Average Recall@5 0.037
# Average Recall@20 0.102
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 1, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.021
# MRR@20 0.026
# Average Recall@5 0.039
# Average Recall@20 0.088
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 1, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.021
# MRR@20 0.027
# Average Recall@5 0.037
# Average Recall@20 0.097
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 1, 'alpha': 100, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.01
# MRR@20 0.015
# Average Recall@5 0.018
# Average Recall@20 0.072
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.024
# MRR@20 0.03
# Average Recall@5 0.044
# Average Recall@20 0.116
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.023
# MRR@20 0.028
# Average Recall@5 0.044
# Average Recall@20 0.099
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.024
# MRR@20 0.029
# Average Recall@5 0.042
# Average Recall@20 0.099
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.022
# MRR@20 0.028
# Average Recall@5 0.043
# Average Recall@20 0.104
# Training model WTF with hyperparameters {'k': 80, 'l2': 100, 'v': 1, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.023
# MRR@20 0.03
# Average Recall@5 0.038
# Average Recall@20 0.108
# Training model WTF with hyperparameters {'k': 80, 'l2': 500, 'v': 1, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.021
# MRR@20 0.026
# Average Recall@5 0.039
# Average Recall@20 0.085
# Training model WTF with hyperparameters {'k': 80, 'l2': 1000, 'v': 1, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.022
# MRR@20 0.027
# Average Recall@5 0.039
# Average Recall@20 0.093
# Training model WTF with hyperparameters {'k': 80, 'l2': 2000, 'v': 1, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.023
# MRR@20 0.029
# Average Recall@5 0.042
# Average Recall@20 0.102
# CPU times: user 7min 29s, sys: 2min 36s, total: 10min 5s
# Wall time: 14min 16s
# "Best score of 0.030340931471676783 achieved with {'k': 80, 'l2': 100, 'v': 0.75, 'alpha': 200, 'max_iterations': 10, 'default_context_1': True, 'max_cg_iter': 10}."

# %% [markdown]
# ## Evaluate model with optimal hyperparams with KFolds Cross validation

# %%
# %%time
alg = ALG(**best_hyperparams)
results = evaluation.cars.contextKFoldsEval(alg, data, nr_folds=5, seed=SEED2, retarget=RETARGET)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
#   0%|          | 0/10 [00:00<?, ?it/s]
# Evaluating with 2362 users
# MRR@5 0.025 (0.002)
# MRR@20 0.031 (0.003)
# Average Recall@5 0.047 (0.003)
# Average Recall@20 0.109 (0.007)
# CPU times: user 57.4 s, sys: 18.9 s, total: 1min 16s
# Wall time: 1min 48s
